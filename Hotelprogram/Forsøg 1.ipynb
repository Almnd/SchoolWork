# %%
library(dplyr)

# %%
library(lubridate)

# %%
library(tidyverse)

# %%
library(ggplot2)

# %%
data = read.csv('hotel_bookings.csv')

# %%
data %>%   

group_by(Arrival_Date = dmy(paste(arrival_date_day_of_month, arrival_date_month, arrival_date_year,sep = "-")))  %>%

summarise(is_canceled = sum(is_canceled ==1))


#Kombinere de 3 forskellige dato kolloner(år,måned,dag) til en enkelt kollone kaldet "Arrival_Date"

#Gruppere arrival-dato ud fra  summen af antallet der har aflyst på samme dato


# Left
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#     Arrival_Date is_canceled
# 1   2015-07-01    19
# 2   2015-07-02    57
# 3   2015-07-03    19
# 4   2015-07-04    43
# 5   2015-07-05    16
# 6   2015-07-06    34
# 7   2015-07-07    25
# 8   2015-07-08    24
# 9   2015-07-09    51
# 10  2015-07-10     9
# 11  2015-07-11    42
# 12  2015-07-12    26
# 13  2015-07-13    45
# 14  2015-07-14    11
# 15  2015-07-15    48
# 16  2015-07-16    62
# 17  2015-07-17    45
# 18  2015-07-18    78
# 19  2015-07-19    18
# 20  2015-07-20    72
# 21  2015-07-21    44
# 22  2015-07-22    84
# 23  2015-07-23    59
# 24  2015-07-24    15
# 25  2015-07-25   103
# 26  2015-07-26    15
# 27  2015-07-27    97
# 28  2015-07-28     6
# 29  2015-07-29    16
# 30  2015-07-30    58
# ... ...          ...
# 764 2017-08-02   48
# 765 2017-08-03   69
# 766 2017-08-04   57
# 767 2017-08-05   60
# 768 2017-08-06   57
# 769 2017-08-07   73
# 770 2017-08-08   54
# 771 2017-08-09   49
# ...
